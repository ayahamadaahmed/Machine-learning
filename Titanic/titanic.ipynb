# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(0), inplace=True)
# Out:
# C:\Users\ayaha\AppData\Local\Temp\ipykernel_22000\2575353491.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(0), inplace=True)

# %%
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\ayaha\AppData\Local\Temp\ipykernel_22000\1964997694.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
df['deck'].fillna(df['deck'].mode()[0], inplace=True)
# Out:
# C:\Users\ayaha\AppData\Local\Temp\ipykernel_22000\3507969400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
# C:\Users\ayaha\AppData\Local\Temp\ipykernel_22000\3507969400.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['deck'].fillna(df['deck'].mode()[0], inplace=True)

# %%
df.drop(['alive','alone','who','embark_town'], axis=1,inplace=True)

# %%
df['family_size'] = df['parch'] + df['sibsp']

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  family_size
# 0        True    C            1
# 1       False    C            1
# 2       False    C            0
# 3       False    C            1
# 4        True    C            0

# %%
df.drop(['sibsp','parch'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age     fare embarked  class  adult_male deck  \
# 0         0       3    male  22.0   7.2500        S  Third        True    C
# 1         1       1  female  38.0  71.2833        C  First       False    C
# 2         1       3  female  26.0   7.9250        S  Third       False    C
# 3         1       1  female  35.0  53.1000        S  First       False    C
# 4         0       3    male  35.0   8.0500        S  Third        True    C
#
#    family_size
# 0            1
# 1            1
# 2            0
# 3            1
# 4            0

# %%
df.drop('class',axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age     fare embarked  adult_male deck  \
# 0         0       3    male  22.0   7.2500        S        True    C
# 1         1       1  female  38.0  71.2833        C       False    C
# 2         1       3  female  26.0   7.9250        S       False    C
# 3         1       1  female  35.0  53.1000        S       False    C
# 4         0       3    male  35.0   8.0500        S        True    C
#
#    family_size
# 0            1
# 1            1
# 2            0
# 3            1
# 4            0

# %%
df=pd.get_dummies(df,columns=['sex', 'embarked'])

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass   age     fare  adult_male  family_size  sex_female  \
# 0         0       3  22.0   7.2500        True            1       False
# 1         1       1  38.0  71.2833       False            1        True
# 2         1       3  26.0   7.9250       False            0        True
# 3         1       1  35.0  53.1000       False            1        True
# 4         0       3  35.0   8.0500        True            0       False
#
#    sex_male  embarked_C  embarked_Q  embarked_S
# 0      True       False       False        True
# 1     False        True       False       False
# 2     False       False       False        True
# 3     False       False       False        True
# 4      True       False       False        True

# %%
df.drop('adult_male', axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass   age     fare  family_size  sex_female  sex_male  \
# 0         0       3  22.0   7.2500            1       False      True
# 1         1       1  38.0  71.2833            1        True     False
# 2         1       3  26.0   7.9250            0        True     False
# 3         1       1  35.0  53.1000            1        True     False
# 4         0       3  35.0   8.0500            0       False      True
#
#    embarked_C  embarked_Q  embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %%
df.drop('sex_female', axis=1,inplace=True)

# %%
df
# Out:
#      survived  pclass        age     fare  family_size  sex_male  embarked_C  \
# 0           0       3  22.000000   7.2500            1      True       False
# 1           1       1  38.000000  71.2833            1     False        True
# 2           1       3  26.000000   7.9250            0     False       False
# 3           1       1  35.000000  53.1000            1     False       False
# 4           0       3  35.000000   8.0500            0      True       False
# ..        ...     ...        ...      ...          ...       ...         ...
# 886         0       2  27.000000  13.0000            0      True       False
# 887         1       1  19.000000  30.0000            0     False       False
# 888         0       3  29.699118  23.4500            3     False       False
# 889         1       1  26.000000  30.0000            0      True        True
# 890         0       3  32.000000   7.7500            0      True       False
#
#      embarked_Q  embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False        True
# 4         False        True
# ..          ...         ...
# 886       False        True
# 887       False        True
# 888       False        True
# 889       False       False
# 890        True       False
#
# [891 rows x 9 columns]

# %%
x = df.drop('survived', axis=1)
y = df['survived']

# %%
y.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy: {accuracy*100:.2f}%')
# Out:
# Accuracy: 80.45%

# %%
from sklearn.metrics import classification_report

# %%
print(f'Classiffication Report:\n{classification_report(y_test,y_pred)}')
# Out:
# Classiffication Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       105
#            1       0.78      0.73      0.76        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.79      0.80       179
# weighted avg       0.80      0.80      0.80       179
